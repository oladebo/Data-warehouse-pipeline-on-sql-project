# %% [markdown]
# ## Upload the CSV File for "bronze Layer" to Postgres sql using python to insert data into the table database
#
# - Create a virtual Environment.
# - Install the require library
# - Open the Complete data warehouse pipeline project file where we have source crm and erp.

# %%
## Let import require library to read our dataset and connect to SQL postgress engine

import pandas as pd
import psycopg2
from sqlalchemy import create_engine, text

# %%
## Let profiling by given the username and password our data by connecting postgres sql server

USERNAME ="postgres"
PASSWORD ="password"
HOST ="localhost"
PORT ="5432"
DB_NAME ="DataWarehouse"

#engine = create_engine(f"postgresql+psycopg2://{USERNAME}):{PASSWORD}@{HOST}:{PORT}/{DB_NAME}")

# %%
## Let create the engine from Sqlalchemy

from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:postgres123@localhost:5432/DataWarehouse"
)

# %%
## let see the first postgress maybe it has coonect successfully

from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SELECT version();"))
    print(result.fetchone())
# Out:
# ('PostgreSQL 15.2 on x86_64-apple-darwin20.6.0, compiled by Apple clang version 12.0.0 (clang-1200.0.32.29), 64-bit',)

# %% [markdown]
# ### A. bronze.crm_cust_info

# %%
## Let see & read the Pandas dataframe of dataset

df = pd.read_csv('/Users/user/Desktop/data_wareHouse_pipeline_project /source_crm/cust_info.csv')

# %%
## Let see the first 5Row of our dataset

df.head(5)
# Out:
#    cust_id    cust_key cust_firstname cust_lastname cust_marital_status  \
# 0  11000.0  AW00011000            Jon         Yang                    M
# 1  11001.0  AW00011001         Eugene       Huang                     S
# 2  11002.0  AW00011002          Ruben        Torres                   M
# 3  11003.0  AW00011003        Christy           Zhu                   S
# 4  11004.0  AW00011004      Elizabeth       Johnson                   S
#
#   cust_gender cust_create_date
# 0           M          10/6/25
# 1           M          10/6/25
# 2           M          10/6/25
# 3           F          10/6/25
# 4           F          10/6/25

# %%
## Let connect the dataset to postgres SQl database

df.to_sql(
    name="crm_cust_info",
    con=engine,
    schema="bronze",
    if_exists="replace",
    index=False
)
# Out:
# 494

# %%
## Let test the connection server to our postgress data output was successful in postgres sql

with engine.connect() as conn:
    count = conn.execute(
        text("SELECT COUNT(*) FROM bronze.crm_cust_info;")
    ).scalar()

    print("Rows in postgres:", count)

    sample = conn.execute(
        text("SELECT * FROM bronze.crm_cust_info LIMIT 5;")
    ).fetchall()

    print("Sample data:", sample)
# Out:
# Rows in postgres: 18494
# Sample data: [(11000.0, 'AW00011000', ' Jon', 'Yang ', 'M', 'M', '10/6/25'), (11001.0, 'AW00011001', 'Eugene', 'Huang  ', 'S', 'M', '10/6/25'), (11002.0, 'AW00011002', 'Ruben', ' Torres', 'M', 'M', '10/6/25'), (11003.0, 'AW00011003', 'Christy', '  Zhu', 'S', 'F', '10/6/25'), (11004.0, 'AW00011004', ' Elizabeth', 'Johnson', 'S', 'F', '10/6/25')]

# %% [markdown]
# ### B. bronze.crm_prod_info

# %%
df = pd.read_csv('/Users/user/Desktop/data_wareHouse_pipeline_project /source_crm/prod_info.csv')

# %%
## Let see the first 5Row of our dataset

df.head(5)
# Out:
#    prod_id          prod_key                  prod_name  prod_cost prod_line  \
# 0      210  CO-RF-FR-R92B-58  HL Road Frame - Black- 58        NaN        R
# 1      211  CO-RF-FR-R92R-58    HL Road Frame - Red- 58        NaN        R
# 2      212   AC-HE-HL-U509-R      Sport-100 Helmet- Red       12.0        S
# 3      213   AC-HE-HL-U509-R      Sport-100 Helmet- Red       14.0        S
# 4      214   AC-HE-HL-U509-R      Sport-100 Helmet- Red       13.0        S
#
#   prod_start_date prod_end_date
# 0          7/1/03           NaN
# 1          7/1/03           NaN
# 2          7/1/11      12/28/07
# 3          7/1/12      12/27/08
# 4          7/1/13           NaN

# %%
## Let connect the dataset to postgres SQl database

df.to_sql(
    name="crm_prod_info",
    con=engine,
    schema="bronze",
    if_exists="replace",
    index=False
)
# Out:
# 397

# %%
## Let test the connection server to our postgress data output was successful in postgres sql

with engine.connect() as conn:
    count = conn.execute(
        text("SELECT COUNT(*) FROM bronze.crm_prod_info;")
    ).scalar()

    print("Rows in postgres:", count)

    sample = conn.execute(
        text("SELECT * FROM bronze.crm_prod_info LIMIT 5;")
    ).fetchall()

    print("Sample data:", sample)
# Out:
# Rows in postgres: 397
# Sample data: [(210, 'CO-RF-FR-R92B-58', 'HL Road Frame - Black- 58', None, 'R ', '7/1/03', None), (211, 'CO-RF-FR-R92R-58', 'HL Road Frame - Red- 58', None, 'R ', '7/1/03', None), (212, 'AC-HE-HL-U509-R', 'Sport-100 Helmet- Red', 12.0, 'S ', '7/1/11', '12/28/07'), (213, 'AC-HE-HL-U509-R', 'Sport-100 Helmet- Red', 14.0, 'S ', '7/1/12', '12/27/08'), (214, 'AC-HE-HL-U509-R', 'Sport-100 Helmet- Red', 13.0, 'S ', '7/1/13', None)]

# %% [markdown]
# ### C. bronze.crm_sales_details

# %%
## Let see & read the Pandas dataframe of dataset

df = pd.read_csv('/Users/user/Desktop/data_wareHouse_pipeline_project /source_crm/sales_details.csv')

# %%
## Let see the first 5Row of our dataset

df.head(5)
# Out:
#   sales_ord_num sales_prod_key  sales_cust_id  sales_order_date  \
# 0       SO43697     BK-R93R-62          21768          20101229
# 1       SO43698     BK-M82S-44          28389          20101229
# 2       SO43699     BK-M82S-44          25863          20101229
# 3       SO43700     BK-R50B-62          14501          20101229
# 4       SO43701     BK-M82S-44          11003          20101229
#
#    sales_ship_date  sales_due_date  sales_amount  sales_quantity  sales_price
# 0         20110105        20110110        3578.0               1       3578.0
# 1         20110105        20110110        3400.0               1       3400.0
# 2         20110105        20110110        3400.0               1       3400.0
# 3         20110105        20110110         699.0               1        699.0
# 4         20110105        20110110        3400.0               1       3400.0

# %%
## Let connect the dataset to postgres SQl database

df.to_sql(
    name="crm_sales_details",
    con=engine,
    schema="bronze",
    if_exists="replace",
    index=False
)
# Out:
# 398

# %%
## Let test the connection server to our postgress data output was successful in postgres sql

with engine.connect() as conn:
    count = conn.execute(
        text("SELECT COUNT(*) FROM bronze.crm_sales_details;")
    ).scalar()

    print("Rows in postgres:", count)

    sample = conn.execute(
        text("SELECT * FROM bronze.crm_sales_details LIMIT 5;")
    ).fetchall()

    print("Sample data:", sample)
# Out:
# Rows in postgres: 60398
# Sample data: [('SO43697', 'BK-R93R-62', 21768, 20101229, 20110105, 20110110, 3578.0, 1, 3578.0), ('SO43698', 'BK-M82S-44', 28389, 20101229, 20110105, 20110110, 3400.0, 1, 3400.0), ('SO43699', 'BK-M82S-44', 25863, 20101229, 20110105, 20110110, 3400.0, 1, 3400.0), ('SO43700', 'BK-R50B-62', 14501, 20101229, 20110105, 20110110, 699.0, 1, 699.0), ('SO43701', 'BK-M82S-44', 11003, 20101229, 20110105, 20110110, 3400.0, 1, 3400.0)]

# %% [markdown]
# ### D. bronze.erp_cust_az1

# %%
## Let see & read the Pandas dataframe of dataset

df = pd.read_csv('/Users/user/Desktop/data_wareHouse_pipeline_project /source_erp/cust_az1.csv')

# %%
## Let see the first 5Row of our dataset

df.head(5)
# Out:
#              cid birth_date  gender
# 0  NASAW00011000    10/6/71    Male
# 1  NASAW00011001    5/10/76    Male
# 2  NASAW00011002     2/9/71    Male
# 3  NASAW00011003    8/14/73  Female
# 4  NASAW00011004     8/5/79  Female

# %%
## Let connect the dataset to postgres SQl database

df.to_sql(
    name="erp_cust_az1",
    con=engine,
    schema="bronze",
    if_exists="replace",
    index=False
)
# Out:
# 484

# %%
## Let test the connection server to our postgress data output was successful in postgres sql

with engine.connect() as conn:
    count = conn.execute(
        text("SELECT COUNT(*) FROM bronze.erp_cust_az1;")
    ).scalar()

    print("Rows in postgres:", count)

    sample = conn.execute(
        text("SELECT * FROM bronze.erp_cust_az1 LIMIT 5;")
    ).fetchall()

    print("Sample data:", sample)
# Out:
# Rows in postgres: 18484
# Sample data: [('NASAW00011000', '10/6/71', 'Male'), ('NASAW00011001', '5/10/76', 'Male'), ('NASAW00011002', '2/9/71', 'Male'), ('NASAW00011003', '8/14/73', 'Female'), ('NASAW00011004', '8/5/79', 'Female')]

# %% [markdown]
# ### E. bronze.erp_loc_a101

# %%
## Let see & read the Pandas dataframe of dataset

df = pd.read_csv('/Users/user/Desktop/data_wareHouse_pipeline_project /source_erp/loc_a101.csv')

# %%
## Let see the first 5Row of our dataset

df.head(5)
# Out:
#            cid    country
# 0  AW-00011000  Australia
# 1  AW-00011001  Australia
# 2  AW-00011002  Australia
# 3  AW-00011003  Australia
# 4  AW-00011004  Australia

# %%
## Let connect the dataset to postgres SQl database

df.to_sql(
    name="erp_loc_a101",
    con=engine,
    schema="bronze",
    if_exists="replace",
    index=False
)
# Out:
# 484

# %%
## Let test the connection server to our postgress data output was successful in postgres sql


with engine.connect() as conn:
    count = conn.execute(
        text("SELECT COUNT(*) FROM bronze.erp_loc_a101;")
    ).scalar()

    print("Rows in postgres:", count)

    sample = conn.execute(
        text("SELECT * FROM bronze.erp_loc_a101 LIMIT 5;")
    ).fetchall()

    print("Sample data:", sample)
# Out:
# Rows in postgres: 18484
# Sample data: [('AW-00011000', 'Australia'), ('AW-00011001', 'Australia'), ('AW-00011002', 'Australia'), ('AW-00011003', 'Australia'), ('AW-00011004', 'Australia')]

# %% [markdown]
# ### F. bronze.erp_px_cat_g1v2

# %%
## Let see & read the Pandas dataframe of dataset

df = pd.read_csv('/Users/user/Desktop/data_wareHouse_pipeline_project /source_erp/px_cat_g1v2.csv')

# %%
## Let see the first 5Row of our dataset

df.head(5)
# Out:
#       id     category       sub_category maintenance
# 0  AC_BR  Accessories         Bike Racks         Yes
# 1  AC_BS  Accessories        Bike Stands          No
# 2  AC_BC  Accessories  Bottles and Cages          No
# 3  AC_CL  Accessories           Cleaners         Yes
# 4  AC_FE  Accessories            Fenders          No

# %%
## Let connect the dataset to postgres SQl database

df.to_sql(
    name="erp_px_cat_g1v2",
    con=engine,
    schema="bronze",
    if_exists="replace",
    index=False
)
# Out:
# 37

# %%
## Let test the connection server to our postgress data output was successful in postgres sql


with engine.connect() as conn:
    count = conn.execute(
        text("SELECT COUNT(*) FROM bronze.erp_px_cat_g1v2;")
    ).scalar()

    print("Rows in postgres:", count)

    sample = conn.execute(
        text("SELECT * FROM bronze.erp_px_cat_g1v2 LIMIT 5;")
    ).fetchall()

    print("Sample data:", sample)
# Out:
# Rows in postgres: 37
# Sample data: [('AC_BR', 'Accessories', 'Bike Racks', 'Yes'), ('AC_BS', 'Accessories', 'Bike Stands', 'No'), ('AC_BC', 'Accessories', 'Bottles and Cages', 'No'), ('AC_CL', 'Accessories', 'Cleaners', 'Yes'), ('AC_FE', 'Accessories', 'Fenders', 'No')]
